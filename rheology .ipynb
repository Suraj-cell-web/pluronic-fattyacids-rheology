# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as plt

# %%
df = pd.read_csv('r''C:\Users\Suraj\OneDrive\Desktop\priya data\PLU+LA&SA 18% VISCOSITY.csv')
# Out:
#   Cell In[8], line 1
#     df = pd.read_csv('r''C:\Users\Suraj\OneDrive\Desktop\priya data\PLU+LA&SA 18% VISCOSITY.csv')
#                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df = pd.read_csv("C:\Users\Suraj\OneDrive\Desktop\priya data\PLU+LA&SA 18% VISCOSITY.csv", encoding="utf-16", sep="\t")
# Out:
#   Cell In[15], line 1
#     df = pd.read_csv("C:\Users\Suraj\OneDrive\Desktop\priya data\PLU+LA&SA 18% VISCOSITY.csv", encoding="utf-16", sep="\t")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df=pd.read_csv(r"C:\Users\Suraj\OneDrive\Desktop\priya data\csvreho.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df=pd.read_csv(r"C:\Users\Suraj\OneDrive\Desktop\priya data\csvreho.csv")
#
# File ~\OneDrive\Documents\pandas app\myenv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df = pd.read_csv(r"C:\Users\Suraj\OneDrive\Desktop\priya data\csvreho.csv", encoding="utf-16", sep=",", engine="python")
df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeError                              Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\Suraj\OneDrive\Desktop\priya data\csvreho.csv", encoding="utf-16", sep=",", engine="python")
#       2 df.head()
#
# ...

# %%
import pandas as pd

with open(r"C:\Users\Suraj\OneDrive\Desktop\priya data\csvreho.csv", "rb") as f:
    raw = f.read().replace(b'\x00', b'')

open("/mnt/data/clean_file.csv", "wb").write(raw)

df = pd.read_csv("/mnt/data/clean_file.csv", encoding="utf-8", engine="python")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 6
#       3 with open(r"C:\Users\Suraj\OneDrive\Desktop\priya data\csvreho.csv", "rb") as f:
#       4     raw = f.read().replace(b'\x00', b'')
# ----> 6 open("/mnt/data/clean_file.csv", "wb").write(raw)
#       8 df = pd.read_csv("/mnt/data/clean_file.csv", encoding="utf-8", engine="python")
#       9 df.head()
#
# File ~\OneDrive\Documents\pandas app\myenv\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# ...

# %%
df = pd.read_csv(r"C:\Users\Suraj\OneDrive\Desktop\priya data\csvreho.csv",
                 encoding="utf-16",
                 sep="\t",
                 engine="python")
# Out:
# ---------------------------------------------------------------------------
# UnicodeError                              Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\Suraj\OneDrive\Desktop\priya data\csvreho.csv",
#       2                  encoding="utf-16",
#       3                  sep="\t",
#       4                  engine="python")
#
# ...

# %%
import pandas as pd

file_path = r"C:\Users\Suraj\OneDrive\Desktop\priya data\csvreho.csv"

# Step 1: Remove NULL bytes that break encoding
with open(file_path, "rb") as f:
    raw = f.read().replace(b'\x00', b'')

# Step 2: Save cleaned version
clean_path = r"C:\Users\Suraj\OneDrive\Desktop\priya data\csvreho.csv"
with open(clean_path, "wb") as f:
    f.write(raw)

# Step 3: Load with auto-detection
df = pd.read_csv(clean_path, engine="python")

df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[27], line 15
#      12     f.write(raw)
#      14 # Step 3: Load with auto-detection
# ---> 15 df = pd.read_csv(clean_path, engine="python")
#      17 df.head()
#
# ...

# %%
df=pd.read_csv(r"C:\Users\Suraj\Downloads\Book.csv",encoding="utf-16", sep=",", engine="python")
# Out:
# ---------------------------------------------------------------------------
# UnicodeError                              Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df=pd.read_csv(r"C:\Users\Suraj\Downloads\Book.csv",encoding="utf-16", sep=",", engine="python")
#
# File ~\OneDrive\Documents\pandas app\myenv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

# Path of your uploaded file
file_path = r"C:\Users\Suraj\Downloads\Book.csv"

# Load using correct encoding
df = pd.read_csv(r"C:\Users\Suraj\Downloads\Book.csv", encoding="latin1")

# Show first 10 rows
df.head(10)
# Out:
#    Point No. Shear Rate Shear Stress Viscosity Temperature   Torque
# 0        NaN        NaN          NaN       NaN         NaN      NaN
# 1        NaN      [1/s]         [Pa]   [mPa·s]        [°C]   [mN·m]
# 2        1.0        0.1        160.2  1.60E+06          25  0.73722
# 3        2.0      0.141       167.25  1.18E+06          25  0.76966
# 4        3.0        0.2       174.55  8.75E+05          25  0.80329
# 5        4.0      0.282       182.39  6.47E+05          25  0.83937
# 6        5.0      0.398       190.71  4.79E+05          25  0.87765
# 7        6.0      0.562       199.21  3.54E+05          25  0.91677
# 8        7.0      0.794       207.32  2.61E+05          25  0.95406
# 9        8.0       1.12       210.52  1.88E+05          25  0.96879

# %%
df.head()
# Out:
#    Point No. Shear Rate Shear Stress Viscosity Temperature   Torque
# 0        NaN        NaN          NaN       NaN         NaN      NaN
# 1        NaN      [1/s]         [Pa]   [mPa·s]        [°C]   [mN·m]
# 2        1.0        0.1        160.2  1.60E+06          25  0.73722
# 3        2.0      0.141       167.25  1.18E+06          25  0.76966
# 4        3.0        0.2       174.55  8.75E+05          25  0.80329

# %%
df = df.drop([0,1])  # delete row 0 and 1
df = df.reset_index(drop=True)
df.head()
# Out:
#    Point No. Shear Rate Shear Stress Viscosity Temperature   Torque
# 0        2.0      0.141       167.25  1.18E+06          25  0.76966
# 1        3.0        0.2       174.55  8.75E+05          25  0.80329
# 2        4.0      0.282       182.39  6.47E+05          25  0.83937
# 3        5.0      0.398       190.71  4.79E+05          25  0.87765
# 4        6.0      0.562       199.21  3.54E+05          25  0.91677

# %%
df.head()
# Out:
#    Point No. Shear Rate Shear Stress Viscosity Temperature   Torque
# 0        2.0      0.141       167.25  1.18E+06          25  0.76966
# 1        3.0        0.2       174.55  8.75E+05          25  0.80329
# 2        4.0      0.282       182.39  6.47E+05          25  0.83937
# 3        5.0      0.398       190.71  4.79E+05          25  0.87765
# 4        6.0      0.562       199.21  3.54E+05          25  0.91677

# %%
cols = ["Point No.", "Shear Rate", "Shear Stress", "Viscosity", "Temperature", "Torque"]

for c in cols:
    df[c] = pd.to_numeric(df[c], errors="coerce")

# %%
df
# Out:
#     Point No.  Shear Rate  Shear Stress  Viscosity  Temperature   Torque
# 0         2.0       0.141        167.25  1180000.0           25  0.76966
# 1         3.0       0.200        174.55   875000.0           25  0.80329
# 2         4.0       0.282        182.39   647000.0           25  0.83937
# 3         5.0       0.398        190.71   479000.0           25  0.87765
# 4         6.0       0.562        199.21   354000.0           25  0.91677
# 5         7.0       0.794        207.32   261000.0           25  0.95406
# 6         8.0       1.120        210.52   188000.0           25  0.96879
# 7         9.0       1.580        204.30   129000.0           25  0.94017
# 8        10.0       2.240        166.58    74415.0           25  0.76658
# 9        11.0       3.160        168.06    53147.0           25  0.77340
# 10       12.0       4.470        191.26    42825.0           25  0.88019
# 11       13.0       6.310        158.80    25167.0           25  0.73078
# ...

# %%
df = df.drop_duplicates()
df = df.reset_index(drop=True)

# %%
df
# Out:
#     Point No.  Shear Rate  Shear Stress  Viscosity  Temperature   Torque
# 0         2.0       0.141        167.25  1180000.0           25  0.76966
# 1         3.0       0.200        174.55   875000.0           25  0.80329
# 2         4.0       0.282        182.39   647000.0           25  0.83937
# 3         5.0       0.398        190.71   479000.0           25  0.87765
# 4         6.0       0.562        199.21   354000.0           25  0.91677
# 5         7.0       0.794        207.32   261000.0           25  0.95406
# 6         8.0       1.120        210.52   188000.0           25  0.96879
# 7         9.0       1.580        204.30   129000.0           25  0.94017
# 8        10.0       2.240        166.58    74415.0           25  0.76658
# 9        11.0       3.160        168.06    53147.0           25  0.77340
# 10       12.0       4.470        191.26    42825.0           25  0.88019
# 11       13.0       6.310        158.80    25167.0           25  0.73078
# ...

# %%
df = df.dropna(how="all")
df
# Out:
#     Point No.  Shear Rate  Shear Stress  Viscosity  Temperature   Torque
# 0         2.0       0.141        167.25  1180000.0           25  0.76966
# 1         3.0       0.200        174.55   875000.0           25  0.80329
# 2         4.0       0.282        182.39   647000.0           25  0.83937
# 3         5.0       0.398        190.71   479000.0           25  0.87765
# 4         6.0       0.562        199.21   354000.0           25  0.91677
# 5         7.0       0.794        207.32   261000.0           25  0.95406
# 6         8.0       1.120        210.52   188000.0           25  0.96879
# 7         9.0       1.580        204.30   129000.0           25  0.94017
# 8        10.0       2.240        166.58    74415.0           25  0.76658
# 9        11.0       3.160        168.06    53147.0           25  0.77340
# 10       12.0       4.470        191.26    42825.0           25  0.88019
# 11       13.0       6.310        158.80    25167.0           25  0.73078
# ...

# %%
df = df.dropna(subset=["Shear Rate", "Shear Stress", "Viscosity"])
df = df.reset_index(drop=True)

# %%
df
# Out:
#     Point No.  Shear Rate  Shear Stress  Viscosity  Temperature   Torque
# 0         2.0       0.141        167.25  1180000.0           25  0.76966
# 1         3.0       0.200        174.55   875000.0           25  0.80329
# 2         4.0       0.282        182.39   647000.0           25  0.83937
# 3         5.0       0.398        190.71   479000.0           25  0.87765
# 4         6.0       0.562        199.21   354000.0           25  0.91677
# 5         7.0       0.794        207.32   261000.0           25  0.95406
# 6         8.0       1.120        210.52   188000.0           25  0.96879
# 7         9.0       1.580        204.30   129000.0           25  0.94017
# 8        10.0       2.240        166.58    74415.0           25  0.76658
# 9        11.0       3.160        168.06    53147.0           25  0.77340
# 10       12.0       4.470        191.26    42825.0           25  0.88019
# 11       13.0       6.310        158.80    25167.0           25  0.73078
# ...

# %%
df.head(20)
# Out:
#     Point No.  Shear Rate  Shear Stress  Viscosity  Temperature   Torque
# 0         2.0       0.141        167.25  1180000.0           25  0.76966
# 1         3.0       0.200        174.55   875000.0           25  0.80329
# 2         4.0       0.282        182.39   647000.0           25  0.83937
# 3         5.0       0.398        190.71   479000.0           25  0.87765
# 4         6.0       0.562        199.21   354000.0           25  0.91677
# 5         7.0       0.794        207.32   261000.0           25  0.95406
# 6         8.0       1.120        210.52   188000.0           25  0.96879
# 7         9.0       1.580        204.30   129000.0           25  0.94017
# 8        10.0       2.240        166.58    74415.0           25  0.76658
# 9        11.0       3.160        168.06    53147.0           25  0.77340
# 10       12.0       4.470        191.26    42825.0           25  0.88019
# 11       13.0       6.310        158.80    25167.0           25  0.73078
# ...

# %%
df.to_csv("clean_rheometer.csv", index=False)

# %%
df
# Out:
#     Point No.  Shear Rate  Shear Stress  Viscosity  Temperature   Torque
# 0         2.0       0.141        167.25  1180000.0           25  0.76966
# 1         3.0       0.200        174.55   875000.0           25  0.80329
# 2         4.0       0.282        182.39   647000.0           25  0.83937
# 3         5.0       0.398        190.71   479000.0           25  0.87765
# 4         6.0       0.562        199.21   354000.0           25  0.91677
# 5         7.0       0.794        207.32   261000.0           25  0.95406
# 6         8.0       1.120        210.52   188000.0           25  0.96879
# 7         9.0       1.580        204.30   129000.0           25  0.94017
# 8        10.0       2.240        166.58    74415.0           25  0.76658
# 9        11.0       3.160        168.06    53147.0           25  0.77340
# 10       12.0       4.470        191.26    42825.0           25  0.88019
# 11       13.0       6.310        158.80    25167.0           25  0.73078
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.plot(df["Shear Rate"], df["Shear Stress"], marker='o')
plt.xlabel("Shear Rate (1/s)")
plt.ylabel("Shear Stress (Pa)")
plt.title("Flow Curve: Shear Stress vs Shear Rate")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.plot(df["Shear Rate"], df["Viscosity"], marker='o')
plt.xlabel("Shear Rate (1/s)")
plt.ylabel("Viscosity (mPa·s)")
plt.title("Viscosity vs Shear Rate")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.loglog(df["Shear Rate"], df["Shear Stress"], 'o')
plt.xlabel("Shear Rate (1/s)")
plt.ylabel("Shear Stress (Pa)")
plt.title("Log-Log Flow Curve")
plt.grid(True, which="both")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.loglog(df["Shear Rate"], df["Viscosity"], 'o')
plt.xlabel("Shear Rate (1/s)")
plt.ylabel("Viscosity (mPa·s)")
plt.title("Log-Log Viscosity Curve")
plt.grid(True, which="both")
plt.show()

# %%
import numpy as np

# Extract data
x = df["Shear Rate"].astype(float)
y = df["Shear Stress"].astype(float)

# Remove any zero or negative values (log cannot process)
mask = (x > 0) & (y > 0)
x = x[mask]
y = y[mask]

# Log-transform
logx = np.log(x)
logy = np.log(y)

# Linear regression on log-log data
coeff = np.polyfit(logx, logy, 1)
n = coeff[0]             # Flow behavior index
logK = coeff[1]
K = np.exp(logK)         # Consistency index

print("Flow behavior index n =", n)
print("Consistency index K =", K)
# Out:
# Flow behavior index n = 0.042534292159947105
# Consistency index K = 185.4031226546521

# %%
# Predicted stress using fitted model
y_pred = K * x**n

plt.figure(figsize=(6,4))
plt.loglog(x, y, 'o', label="Experimental Data")
plt.loglog(x, y_pred, '-', label=f"Power-law Fit (K={K:.3e}, n={n:.3f})")

plt.xlabel("Shear Rate (1/s)")
plt.ylabel("Shear Stress (Pa)")
plt.title("Power-law Fit on Log-Log Scale")
plt.grid(True, which="both")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
def HB_model(gamma, tau0, K, n):
    return tau0 + K * (gamma ** n)

# %%
gamma = df["Shear Rate"].astype(float).values       # shear rate
tau = df["Shear Stress"].astype(float).values       # shear stress

# Keep only positive values (HB cannot fit zeros)
mask = (gamma > 0) & (tau > 0)
gamma = gamma[mask]
tau = tau[mask]

# %%
# initial guess: tau0, K, n
initial_guess = [1, 100, 0.1]

popt, pcov = curve_fit(HB_model, gamma, tau, p0=initial_guess, maxfev=50000)

tau0, K_HB, n_HB = popt

print("Yield Stress (tau0) =", tau0)
print("Consistency Index (K) =", K_HB)
print("Flow Index (n) =", n_HB)
# Out:
# Yield Stress (tau0) = 183.17938590858347
# Consistency Index (K) = 0.46577003094534447
# Flow Index (n) = 1.165856550349872

# %%
gamma_fit = np.linspace(min(gamma), max(gamma), 200)
tau_fit = HB_model(gamma_fit, tau0, K_HB, n_HB)

plt.figure(figsize=(6,4))
plt.loglog(gamma, tau, 'o', label="Experimental Data")
plt.loglog(gamma_fit, tau_fit, '-', label="HB Fit")

plt.xlabel("Shear Rate (1/s)")
plt.ylabel("Shear Stress (Pa)")
plt.title("Herschel–Bulkley Fit")
plt.grid(True, which="both")
plt.legend()
plt.show()

# %%
df = pd.read_csv(r"C:\Users\Suraj\Downloads\All excel of peptide +transethosomes.csv", header=None, names=["wavelength", "ellipticity"])
df = df.dropna()
df.head()
# Out:
#                                                                                                                                                                                                                                                                                           wavelength  \
# Wavelength [nm] CD [mdeg] NaN Wavelength [nm] CD [mdeg]   NaN Wavelength [nm] CD [mdeg] NaN Wavelength [nm] CD [mdeg] NaN Wavelength [nm] CD [mdeg] NaN Wavelength [nm] CD [mdeg]   NaN Wavelength [nm] CD [mdeg] NaN Wavelength [nm] CD [mdeg]   NaN Wavelength [nm] CD [mdeg] NaN  Wavelength [nm]
# 350             0.36724   NaN 350             -0.00644805 NaN 350             0.0959986 NaN 350             0.415335  NaN 350             -1.25993  NaN 350             -0.171543   NaN 350             -0.20181  NaN 350             -0.145895   NaN 350             0.275281  NaN              350
# ...

# %%
plt.figure(figsize=(8,5))
plt.plot(df["wavelength"], df["ellipticity"])
plt.gca().invert_xaxis()  # CD convention: low nm on left
plt.xlabel("Wavelength (nm)")
plt.ylabel("Ellipticity (mdeg)")
plt.title("Raw CD Spectrum")
plt.grid(True)
plt.show()

# %%
df["smooth"] = savgol_filter(df["ellipticity"], window_length=11, polyorder=3)

plt.figure(figsize=(8,5))
plt.plot(df["wavelength"], df["ellipticity"], alpha=0.4, label="raw")
plt.plot(df["wavelength"], df["smooth"], label="smoothed")
plt.gca().invert_xaxis()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df["smooth"] = savgol_filter(df["ellipticity"], window_length=11, polyorder=3)
#       3 plt.figure(figsize=(8,5))
#       4 plt.plot(df["wavelength"], df["ellipticity"], alpha=0.4, label="raw")
#
# NameError: name 'savgol_filter' is not defined
